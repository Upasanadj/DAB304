# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from numpy import genfromtxt
from mpl_toolkits.mplot3d import Axes3D

# %%
## Reading input data
HR_df = pd.read_csv("HR.csv")
BVP_df = pd.read_csv("BVP.csv")
TEMP_df = pd.read_csv("TEMP.csv")
EDA_df = pd.read_csv("EDA.csv")
ACC1_df = pd.read_csv("ACC1.csv")

# %%
## Data summary 
HR_df.info()
TEMP_df.info()
EDA_df.info()
BVP_df.info()

# %%
## statistical details for dataframe
HR_df.describe(include='all')
TEMP_df.describe(include='all')
EDA_df.describe(include='all')
BVP_df.describe(include='all')

# %%
### NULL Value check
HR_df.isnull().sum()

# %%
EDA_df.isnull().sum()

# %%
TEMP_df.isnull().sum()

# %%
BVP_df.isnull().sum()

# %%
ACC1_df.isnull().sum()

# %%
## Dropping NULL Values
HR_df_clean = HR_df.dropna()
TEMP_df_clean = TEMP_df.dropna()
EDA_df_clean = EDA_df.dropna()
BVP_df_clean = BVP_df.dropna()

# %%
## Rechecking NULL Values after dropping nulls
print(HR_df_clean.isnull().sum())
print(TEMP_df_clean.isnull().sum())
print(EDA_df_clean.isnull().sum())
print(BVP_df_clean.isnull().sum())

# %%
## Dropping index columns
HR_df_clean = HR_df_clean.drop(columns=['Unnamed: 0'])
TEMP_df_clean = TEMP_df_clean.drop(columns=['Unnamed: 0'])
EDA_df_clean = EDA_df_clean.drop(columns=['Unnamed: 0'])
BVP_df_clean = BVP_df_clean.drop(columns=['Unnamed: 0'])
ACC1_df_clean = ACC1_df.drop(columns=['StudentNum','Unnamed: 0'])

# %%
### Univariate Analysis
HR_df_clean.hist(grid=True, color='gray',bins=30,figsize=(15, 10),edgecolor='black')
# Out:
# array([[<AxesSubplot:title={'center':'ExamType'}>,
#         <AxesSubplot:title={'center':'HR1'}>,
#         <AxesSubplot:title={'center':'HR2'}>],
#        [<AxesSubplot:title={'center':'HR3'}>,
#         <AxesSubplot:title={'center':'HR4'}>,
#         <AxesSubplot:title={'center':'HR5'}>],
#        [<AxesSubplot:title={'center':'HR6'}>,
#         <AxesSubplot:title={'center':'HR7'}>,
#         <AxesSubplot:title={'center':'HR8'}>],
#        [<AxesSubplot:title={'center':'HR9'}>,
#         <AxesSubplot:title={'center':'HR10'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
TEMP_df_clean.hist(grid=True, color='skyblue',bins=30,figsize=(15, 10),edgecolor='black')
# Out:
# array([[<AxesSubplot:title={'center':'ExamType'}>,
#         <AxesSubplot:title={'center':'TEMP1'}>,
#         <AxesSubplot:title={'center':'TEMP2'}>],
#        [<AxesSubplot:title={'center':'TEMP3'}>,
#         <AxesSubplot:title={'center':'TEMP4'}>,
#         <AxesSubplot:title={'center':'TEMP5'}>],
#        [<AxesSubplot:title={'center':'TEMP6'}>,
#         <AxesSubplot:title={'center':'TEMP7'}>,
#         <AxesSubplot:title={'center':'TEMP8'}>],
#        [<AxesSubplot:title={'center':'TEMP9'}>,
#         <AxesSubplot:title={'center':'TEMP10'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# Heatmap for bivariate analysis HEART RATE
corr = HR_df_clean.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):    
    f, ax = plt.subplots(figsize=(8, 6))    
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True, cmap="coolwarm",annot=True)

# %%
# Heatmap for bivariate analysis TEMP
corr = TEMP_df_clean.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):    
    f, ax = plt.subplots(figsize=(8, 6))    
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True, cmap="coolwarm",annot=True)

# %%
# Heatmap for bivariate analysis EDA
corr = EDA_df_clean.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):    
    f, ax = plt.subplots(figsize=(8, 6))    
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True, cmap="coolwarm",annot=True)

# %%
# Heatmap for bivariate analysis BVP
corr = BVP_df_clean.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):    
    f, ax = plt.subplots(figsize=(8, 6))    
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True, cmap="coolwarm",annot=True)

# %%
import pandas as pd
import datetime

########################################################################################   Midterm 1 exam
unixts = datetime.datetime.fromtimestamp(1539435376)

input_file = "Data/S1/Midterm 1/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 1, ExamType = 2)
df_1_HR_F = new_df.reset_index(drop=True)
df_1_HR_F.columns=['HR1','StudentNum','ExamType']
df_1_HR_M1=df_1_HR_F.drop(0)
df_1_HR_M1['time'] = pd.date_range(unixts, freq='1min', periods=len(df_1_HR_M1))

input_file = "Data/S2/Midterm 1/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 2, ExamType = 2)
df_2_HR_F = new_df.reset_index(drop=True)
df_2_HR_F.columns=['HR2','StudentNum','ExamType']
df_2_HR_M1=df_2_HR_F.drop(0)
df_2_HR_M1['time'] = pd.date_range(unixts, freq='1min', periods=len(df_2_HR_M1))
 
input_file = "Data/S3/Midterm 1/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 3, ExamType = 2)
df_3_HR_F = new_df.reset_index(drop=True)
df_3_HR_F.columns=['HR3','StudentNum','ExamType']
df_3_HR_M1=df_3_HR_F.drop(0)
df_3_HR_M1['time'] = pd.date_range(unixts, freq='1min', periods=len(df_3_HR_M1))

input_file = "Data/S4/Midterm 1/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 4, ExamType = 2)
df_4_HR_F = new_df.reset_index(drop=True)
df_4_HR_F.columns=['HR4','StudentNum','ExamType']
df_4_HR_M1=df_4_HR_F.drop(0)
df_4_HR_M1['time'] = pd.date_range(unixts, freq='1min', periods=len(df_4_HR_M1))

input_file = "Data/S5/Midterm 1/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 5, ExamType = 2)
df_5_HR_F = new_df.reset_index(drop=True)
df_5_HR_F.columns=['HR5','StudentNum','ExamType']
df_5_HR_M1=df_5_HR_F.drop(0)
df_5_HR_M1['time'] = pd.date_range(unixts, freq='1min', periods=len(df_5_HR_M1))

input_file = "Data/S6/Midterm 1/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 6, ExamType = 2)
df_6_HR_F = new_df.reset_index(drop=True)
df_6_HR_F.columns=['HR6','StudentNum','ExamType']
df_6_HR_M1=df_6_HR_F.drop(0)
df_6_HR_M1['time'] = pd.date_range(unixts, freq='1min', periods=len(df_6_HR_M1))

input_file = "Data/S7/Midterm 1/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 7, ExamType = 2)
df_7_HR_F = new_df.reset_index(drop=True)
df_7_HR_F.columns=['HR7','StudentNum','ExamType']
df_7_HR_M1=df_7_HR_F.drop(0)
df_7_HR_M1['time'] = pd.date_range(unixts, freq='1min', periods=len(df_7_HR_M1))

input_file = "Data/S8/Midterm 1/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 8, ExamType = 2)
df_8_HR_F = new_df.reset_index(drop=True)
df_8_HR_F.columns=['HR8','StudentNum','ExamType']
df_8_HR_M1=df_8_HR_F.drop(0)
df_8_HR_M1['time'] = pd.date_range(unixts, freq='1min', periods=len(df_8_HR_M1))
 
input_file = "Data/S9/Midterm 1/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 9, ExamType = 2)
df_9_HR_F = new_df.reset_index(drop=True)
df_9_HR_F.columns=['HR9','StudentNum','ExamType']
df_9_HR_M1=df_9_HR_F.drop(0)
df_9_HR_M1['time'] = pd.date_range(unixts, freq='1min', periods=len(df_9_HR_M1))

 
input_file = "Data/S10/Midterm 1/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 10, ExamType = 2)
df_10_HR_F = new_df.reset_index(drop=True)
df_10_HR_F.columns=['HR10','StudentNum','ExamType']
df_10_HR_M1=df_10_HR_F.drop(0)
df_10_HR_M1['time'] = pd.date_range(unixts, freq='1min', periods=len(df_10_HR_M1))


df_HR = df_1_HR_M1.join(df_2_HR_M1["HR2"])
df_HR = df_HR.join(df_3_HR_M1["HR3"])
df_HR = df_HR.join(df_4_HR_M1["HR4"])
df_HR = df_HR.join(df_5_HR_M1["HR5"])
df_HR = df_HR.join(df_6_HR_M1["HR6"])
df_HR = df_HR.join(df_7_HR_M1["HR7"])
df_HR = df_HR.join(df_8_HR_M1["HR8"])
df_HR = df_HR.join(df_9_HR_M1["HR9"])
df_HR = df_HR.join(df_10_HR_M1["HR10"])

df_HR_Midterm1=df_HR.reindex(columns= ['ExamType','time','HR1','HR2','HR3','HR4','HR5','HR6','HR7','HR8','HR9','HR10'])

######################################################################################################   Midterm 2 exam

unixts = datetime.datetime.fromtimestamp(1541859565)

input_file = "Data/S1/Midterm 2/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 1, ExamType = 3)
df_1_HR_F = new_df.reset_index(drop=True)
df_1_HR_F.columns=['HR1','StudentNum','ExamType']
df_1_HR_M2=df_1_HR_F.drop(0)
df_1_HR_M2['time'] = pd.date_range(unixts, freq='1min', periods=len(df_1_HR_M2))

input_file = "Data/S2/Midterm 2/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 2, ExamType = 3)
df_2_HR_F = new_df.reset_index(drop=True)
df_2_HR_F.columns=['HR2','StudentNum','ExamType']
df_2_HR_M2=df_2_HR_F.drop(0)
df_2_HR_M2['time'] = pd.date_range(unixts, freq='1min', periods=len(df_2_HR_M2))
 
input_file = "Data/S3/Midterm 2/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 3, ExamType = 3)
df_3_HR_F = new_df.reset_index(drop=True)
df_3_HR_F.columns=['HR3','StudentNum','ExamType']
df_3_HR_M2=df_3_HR_F.drop(0)
df_3_HR_M2['time'] = pd.date_range(unixts, freq='1min', periods=len(df_3_HR_M2))

input_file = "Data/S4/Midterm 2/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 4, ExamType = 3)
df_4_HR_F = new_df.reset_index(drop=True)
df_4_HR_F.columns=['HR4','StudentNum','ExamType']
df_4_HR_M2=df_4_HR_F.drop(0)
df_4_HR_M2['time'] = pd.date_range(unixts, freq='1min', periods=len(df_4_HR_M2))

input_file = "Data/S5/Midterm 2/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 5, ExamType = 3)
df_5_HR_F = new_df.reset_index(drop=True)
df_5_HR_F.columns=['HR5','StudentNum','ExamType']
df_5_HR_M2=df_5_HR_F.drop(0)
df_5_HR_M2['time'] = pd.date_range(unixts, freq='1min', periods=len(df_5_HR_M2))

input_file = "Data/S6/Midterm 2/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 6, ExamType = 3)
df_6_HR_F = new_df.reset_index(drop=True)
df_6_HR_F.columns=['HR6','StudentNum','ExamType']
df_6_HR_M2=df_6_HR_F.drop(0)
df_6_HR_M2['time'] = pd.date_range(unixts, freq='1min', periods=len(df_6_HR_M2))

input_file = "Data/S7/Midterm 2/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 7, ExamType = 3)
df_7_HR_F = new_df.reset_index(drop=True)
df_7_HR_F.columns=['HR7','StudentNum','ExamType']
df_7_HR_M2=df_7_HR_F.drop(0)
df_7_HR_M2['time'] = pd.date_range(unixts, freq='1min', periods=len(df_7_HR_M2))

input_file = "Data/S8/Midterm 2/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 8, ExamType = 3)
df_8_HR_F = new_df.reset_index(drop=True)
df_8_HR_F.columns=['HR8','StudentNum','ExamType']
df_8_HR_M2=df_8_HR_F.drop(0)
df_8_HR_M2['time'] = pd.date_range(unixts, freq='1min', periods=len(df_8_HR_M2))
 
input_file = "Data/S9/Midterm 2/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 9, ExamType = 3)
df_9_HR_F = new_df.reset_index(drop=True)
df_9_HR_F.columns=['HR9','StudentNum','ExamType']
df_9_HR_M2=df_9_HR_F.drop(0)
df_9_HR_M2['time'] = pd.date_range(unixts, freq='1min', periods=len(df_9_HR_M2))

input_file = "Data/S10/Midterm 2/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 10, ExamType = 3)
df_10_HR_F = new_df.reset_index(drop=True)
df_10_HR_F.columns=['HR10','StudentNum','ExamType']
df_10_HR_M2=df_10_HR_F.drop(0)
df_10_HR_M2['time'] = pd.date_range(unixts, freq='1min', periods=len(df_10_HR_M2))

df_HR = pd.DataFrame()

df_HR = df_1_HR_M2.join(df_2_HR_M2["HR2"])
df_HR = df_HR.join(df_3_HR_M2["HR3"])
df_HR = df_HR.join(df_4_HR_M2["HR4"])
df_HR = df_HR.join(df_5_HR_M2["HR5"])
df_HR = df_HR.join(df_6_HR_M2["HR6"])
df_HR = df_HR.join(df_7_HR_M2["HR7"])
df_HR = df_HR.join(df_8_HR_M2["HR8"])
df_HR = df_HR.join(df_9_HR_M2["HR9"])
df_HR = df_HR.join(df_10_HR_M2["HR10"])

df_HR_Midterm2=df_HR.reindex(columns= ['ExamType','time','HR1','HR2','HR3','HR4','HR5','HR6','HR7','HR8','HR9','HR10'])

################################################################################################  Final exam

unixts = datetime.datetime.fromtimestamp(1544027347)

input_file = "Data/S1/Final/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 1, ExamType = 1)
df_1_HR_F = new_df.reset_index(drop=True)
df_1_HR_F.columns=['HR1','StudentNum','ExamType']
df_1_HR_F=df_1_HR_F.drop(0)
df_1_HR_F['time'] = pd.date_range(unixts, freq='1min', periods=len(df_1_HR_F))
 
input_file = "Data/S2/Final/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 2, ExamType = 1)
df_2_HR_F = new_df.reset_index(drop=True)
df_2_HR_F.columns=['HR2','StudentNum','ExamType']
df_2_HR_F=df_2_HR_F.drop(0)
df_2_HR_F['time'] = pd.date_range(unixts, freq='1min', periods=len(df_2_HR_F))
 
input_file = "Data/S3/Final/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 3, ExamType = 1)
df_3_HR_F = new_df.reset_index(drop=True)
df_3_HR_F.columns=['HR3','StudentNum','ExamType']
df_3_HR_F=df_3_HR_F.drop(0)
df_3_HR_F['time'] = pd.date_range(unixts, freq='1min', periods=len(df_3_HR_F))

input_file = "Data/S4/Final/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 4, ExamType = 1)
df_4_HR_F = new_df.reset_index(drop=True)
df_4_HR_F.columns=['HR4','StudentNum','ExamType']
df_4_HR_F=df_4_HR_F.drop(0)
df_4_HR_F['time'] = pd.date_range(unixts, freq='1min', periods=len(df_4_HR_F))
 
input_file = "Data/S5/Final/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 5, ExamType = 1)
df_5_HR_F = new_df.reset_index(drop=True)
df_5_HR_F.columns=['HR5','StudentNum','ExamType']
df_5_HR_F=df_5_HR_F.drop(0)
df_5_HR_F['time'] = pd.date_range(unixts, freq='1min', periods=len(df_5_HR_F))
 
input_file = "Data/S6/Final/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 6, ExamType = 1)
df_6_HR_F = new_df.reset_index(drop=True)
df_6_HR_F.columns=['HR6','StudentNum','ExamType']
df_6_HR_F=df_6_HR_F.drop(0)
df_6_HR_F['time'] = pd.date_range(unixts, freq='1min', periods=len(df_6_HR_F))
 
input_file = "Data/S7/Final/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 7, ExamType = 1)
df_7_HR_F = new_df.reset_index(drop=True)
df_7_HR_F.columns=['HR7','StudentNum','ExamType']
df_7_HR_F=df_7_HR_F.drop(0)
df_7_HR_F['time'] = pd.date_range(unixts, freq='1min', periods=len(df_7_HR_F))
 
input_file = "Data/S8/Final/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 8, ExamType = 1)
df_8_HR_F = new_df.reset_index(drop=True)
df_8_HR_F.columns=['HR8','StudentNum','ExamType']
df_8_HR_F=df_8_HR_F.drop(0)
df_8_HR_F['time'] = pd.date_range(unixts, freq='1min', periods=len(df_8_HR_F))
 
input_file = "Data/S9/Final/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 9, ExamType = 1)
df_9_HR_F = new_df.reset_index(drop=True)
df_9_HR_F.columns=['HR9','StudentNum','ExamType']
df_9_HR_F=df_9_HR_F.drop(0)
df_9_HR_F['time'] = pd.date_range(unixts, freq='1min', periods=len(df_9_HR_F))
 
input_file = "Data/S10/Final/HR.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 10, ExamType = 1)
df_10_HR_F = new_df.reset_index(drop=True)
df_10_HR_F.columns=['HR10','StudentNum','ExamType']
df_10_HR_F=df_10_HR_F.drop(0)
df_10_HR_F['time'] = pd.date_range(unixts, freq='1min', periods=len(df_10_HR_F))
 
df_HR = df_1_HR_F.join(df_2_HR_F["HR2"])
df_HR = df_HR.join(df_3_HR_F["HR3"])
df_HR = df_HR.join(df_4_HR_F["HR4"])
df_HR = df_HR.join(df_5_HR_F["HR5"])
df_HR = df_HR.join(df_6_HR_F["HR6"])
df_HR = df_HR.join(df_7_HR_F["HR7"])
df_HR = df_HR.join(df_8_HR_F["HR8"])
df_HR = df_HR.join(df_9_HR_F["HR9"])
df_HR = df_HR.join(df_10_HR_F["HR10"])

df_HR_Final=df_HR.reindex(columns= ['ExamType','time','HR1','HR2','HR3','HR4','HR5','HR6','HR7','HR8','HR9','HR10'])

#########
sns.set(style='whitegrid', rc={'axes.facecolor': '#EFF2F7'})
plt.plot
settings = {}
settings['fs'] = 390
start = 0
stop = 23387
duration = (stop-start) / settings['fs']

#################################### midterm 1 plot

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 1, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm1[start:stop].time, df_HR_Midterm1[start:stop].HR1, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 2, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm1[start:stop].time, df_HR_Midterm1[start:stop].HR2, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 3, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm1[start:stop].time, df_HR_Midterm1[start:stop].HR3, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 4, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm1[start:stop].time, df_HR_Midterm1[start:stop].HR4, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 5, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm1[start:stop].time, df_HR_Midterm1[start:stop].HR5, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 6, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm1[start:stop].time, df_HR_Midterm1[start:stop].HR6, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 7, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm1[start:stop].time, df_HR_Midterm1[start:stop].HR7, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)") 
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 8, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm1[start:stop].time, df_HR_Midterm1[start:stop].HR8, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 9, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm1[start:stop].time, df_HR_Midterm1[start:stop].HR9, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 10, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm1[start:stop].time, df_HR_Midterm1[start:stop].HR10, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

########################################### Midterm 2 plot

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 1, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm2[start:stop].time, df_HR_Midterm2[start:stop].HR1, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 2, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm2[start:stop].time, df_HR_Midterm2[start:stop].HR2, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 3, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm2[start:stop].time, df_HR_Midterm2[start:stop].HR3, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 4, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm2[start:stop].time, df_HR_Midterm2[start:stop].HR4, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 5, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm2[start:stop].time, df_HR_Midterm2[start:stop].HR5, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 6, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm2[start:stop].time, df_HR_Midterm2[start:stop].HR6, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 7, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm2[start:stop].time, df_HR_Midterm2[start:stop].HR7, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 8, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm2[start:stop].time, df_HR_Midterm2[start:stop].HR8, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 9, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm2[start:stop].time, df_HR_Midterm2[start:stop].HR9, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 10, slice of %.1f seconds" % duration)
plt.plot(df_HR_Midterm2[start:stop].time, df_HR_Midterm2[start:stop].HR10, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

########################### final plot

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 1, slice of %.1f seconds" % duration)
plt.plot(df_HR_Final[start:stop].time, df_HR_Final[start:stop].HR1, color="#51A6D8", linewidth=0.5)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 2, slice of %.1f seconds" % duration)
plt.plot(df_HR_Final[start:stop].time, df_HR_Final[start:stop].HR2, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 3, slice of %.1f seconds" % duration)
plt.plot(df_HR_Final[start:stop].time, df_HR_Final[start:stop].HR3, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 4, slice of %.1f seconds" % duration)
plt.plot(df_HR_Final[start:stop].time, df_HR_Final[start:stop].HR4, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 5, slice of %.1f seconds" % duration)
plt.plot(df_HR_Final[start:stop].time, df_HR_Final[start:stop].HR5, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 6, slice of %.1f seconds" % duration)
plt.plot(df_HR_Final[start:stop].time, df_HR_Final[start:stop].HR6, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 7, slice of %.1f seconds" % duration)
plt.plot(df_HR_Final[start:stop].time, df_HR_Final[start:stop].HR7, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 8, slice of %.1f seconds" % duration)
plt.plot(df_HR_Final[start:stop].time, df_HR_Final[start:stop].HR8, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 9, slice of %.1f seconds" % duration)
plt.plot(df_HR_Final[start:stop].time, df_HR_Final[start:stop].HR9, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Heart rate for student 10, slice of %.1f seconds" % duration)
plt.plot(df_HR_Final[start:stop].time, df_HR_Final[start:stop].HR10, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

# %%
if __name__ == "__main__":

    print("Plotting Accelerometer Data for student 1 movements in all 3 exams")
    
    acm_data = genfromtxt("ACC1.csv", delimiter=',', names="X, Y, Z, StudentNum, ExamType, time")
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    x = acm_data["X"]
    y = acm_data["Y"]
    z = acm_data["Z"]
    c = acm_data["time"]

    ax.scatter(x, y, z, c=c, cmap=plt.hot())
    plt.show()
# Out:
# Plotting Accelerometer Data for student 1 movements in all 3 exams

# %%
data = {'first_column':  ['first_value', 'second_value', ...],
        'second_column': ['first_value', 'second_value', ...],
         ....
        }
