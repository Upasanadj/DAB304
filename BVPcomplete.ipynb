# %%
import pandas as pd
import datetime

########################################################################################   Midterm1 exam
unixts = datetime.datetime.fromtimestamp(1539435366)

input_file = "Data/S1/Midterm 1/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 1, ExamType = 2)
df_1_BVP_F = new_df.reset_index(drop=True)
df_1_BVP_F.columns=['BVP1','StudentNum','ExamType']
df_1_BVP_M1=df_1_BVP_F.drop(0)
df_1_BVP_M1['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_1_BVP_M1))

input_file = "Data/S2/Midterm 1/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 2, ExamType = 2)
df_2_BVP_F = new_df.reset_index(drop=True)
df_2_BVP_F.columns=['BVP2','StudentNum','ExamType']
df_2_BVP_M1=df_2_BVP_F.drop(0)
df_2_BVP_M1['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_2_BVP_M1))
 
input_file = "Data/S3/Midterm 1/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 3, ExamType = 2)
df_3_BVP_F = new_df.reset_index(drop=True)
df_3_BVP_F.columns=['BVP3','StudentNum','ExamType']
df_3_BVP_M1=df_3_BVP_F.drop(0)
df_3_BVP_M1['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_3_BVP_M1))

input_file = "Data/S4/Midterm 1/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 4, ExamType = 2)
df_4_BVP_F = new_df.reset_index(drop=True)
df_4_BVP_F.columns=['BVP4','StudentNum','ExamType']
df_4_BVP_M1=df_4_BVP_F.drop(0)
df_4_BVP_M1['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_4_BVP_M1))

input_file = "Data/S5/Midterm 1/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 5, ExamType = 2)
df_5_BVP_F = new_df.reset_index(drop=True)
df_5_BVP_F.columns=['BVP5','StudentNum','ExamType']
df_5_BVP_M1=df_5_BVP_F.drop(0)
df_5_BVP_M1['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_5_BVP_M1))

input_file = "Data/S6/Midterm 1/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 6, ExamType = 2)
df_6_BVP_F = new_df.reset_index(drop=True)
df_6_BVP_F.columns=['BVP6','StudentNum','ExamType']
df_6_BVP_M1=df_6_BVP_F.drop(0)
df_6_BVP_M1['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_6_BVP_M1))

input_file = "Data/S7/Midterm 1/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 7, ExamType = 2)
df_7_BVP_F = new_df.reset_index(drop=True)
df_7_BVP_F.columns=['BVP7','StudentNum','ExamType']
df_7_BVP_M1=df_7_BVP_F.drop(0)
df_7_BVP_M1['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_7_BVP_M1))

input_file = "Data/S8/Midterm 1/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 8, ExamType = 2)
df_8_BVP_F = new_df.reset_index(drop=True)
df_8_BVP_F.columns=['BVP8','StudentNum','ExamType']
df_8_BVP_M1=df_8_BVP_F.drop(0)
df_8_BVP_M1['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_8_BVP_M1))
 
input_file = "Data/S9/Midterm 1/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 9, ExamType = 2)
df_9_BVP_F = new_df.reset_index(drop=True)
df_9_BVP_F.columns=['BVP9','StudentNum','ExamType']
df_9_BVP_M1=df_9_BVP_F.drop(0)
df_9_BVP_M1['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_9_BVP_M1))

 
input_file = "Data/S10/Midterm 1/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 10, ExamType = 2)
df_10_BVP_F = new_df.reset_index(drop=True)
df_10_BVP_F.columns=['BVP10','StudentNum','ExamType']
df_10_BVP_M1=df_10_BVP_F.drop(0)
df_10_BVP_M1['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_10_BVP_M1))


df_BVP = df_1_BVP_M1.join(df_2_BVP_M1["BVP2"])
df_BVP = df_BVP.join(df_3_BVP_M1["BVP3"])
df_BVP = df_BVP.join(df_4_BVP_M1["BVP4"])
df_BVP = df_BVP.join(df_5_BVP_M1["BVP5"])
df_BVP = df_BVP.join(df_6_BVP_M1["BVP6"])
df_BVP = df_BVP.join(df_7_BVP_M1["BVP7"])
df_BVP = df_BVP.join(df_8_BVP_M1["BVP8"])
df_BVP = df_BVP.join(df_9_BVP_M1["BVP9"])
df_BVP = df_BVP.join(df_10_BVP_M1["BVP10"])

df_BVP_Midterm1=df_BVP.reindex(columns= ['ExamType','time','BVP1','BVP2','BVP3','BVP4','BVP5','BVP6','BVP7','BVP8','BVP9','BVP10'])

######################################################################################################   Midterm 2 exam

unixts = datetime.datetime.fromtimestamp(1541859555)

input_file = "Data/S1/Midterm 2/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 1, ExamType = 3)
df_1_BVP_F = new_df.reset_index(drop=True)
df_1_BVP_F.columns=['BVP1','StudentNum','ExamType']
df_1_BVP_M2=df_1_BVP_F.drop(0)
df_1_BVP_M2['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_1_BVP_M2))

input_file = "Data/S2/Midterm 2/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 2, ExamType = 3)
df_2_BVP_F = new_df.reset_index(drop=True)
df_2_BVP_F.columns=['BVP2','StudentNum','ExamType']
df_2_BVP_M2=df_2_BVP_F.drop(0)
df_2_BVP_M2['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_2_BVP_M2))
 
input_file = "Data/S3/Midterm 2/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 3, ExamType = 3)
df_3_BVP_F = new_df.reset_index(drop=True)
df_3_BVP_F.columns=['BVP3','StudentNum','ExamType']
df_3_BVP_M2=df_3_BVP_F.drop(0)
df_3_BVP_M2['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_3_BVP_M2))

input_file = "Data/S4/Midterm 2/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 4, ExamType = 3)
df_4_BVP_F = new_df.reset_index(drop=True)
df_4_BVP_F.columns=['BVP4','StudentNum','ExamType']
df_4_BVP_M2=df_4_BVP_F.drop(0)
df_4_BVP_M2['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_4_BVP_M2))

input_file = "Data/S5/Midterm 2/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 5, ExamType = 3)
df_5_BVP_F = new_df.reset_index(drop=True)
df_5_BVP_F.columns=['BVP5','StudentNum','ExamType']
df_5_BVP_M2=df_5_BVP_F.drop(0)
df_5_BVP_M2['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_5_BVP_M2))

input_file = "Data/S6/Midterm 2/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 6, ExamType = 3)
df_6_BVP_F = new_df.reset_index(drop=True)
df_6_BVP_F.columns=['BVP6','StudentNum','ExamType']
df_6_BVP_M2=df_6_BVP_F.drop(0)
df_6_BVP_M2['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_6_BVP_M2))

input_file = "Data/S7/Midterm 2/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 7, ExamType = 3)
df_7_BVP_F = new_df.reset_index(drop=True)
df_7_BVP_F.columns=['BVP7','StudentNum','ExamType']
df_7_BVP_M2=df_7_BVP_F.drop(0)
df_7_BVP_M2['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_7_BVP_M2))

input_file = "Data/S8/Midterm 2/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 8, ExamType = 3)
df_8_BVP_F = new_df.reset_index(drop=True)
df_8_BVP_F.columns=['BVP8','StudentNum','ExamType']
df_8_BVP_M2=df_8_BVP_F.drop(0)
df_8_BVP_M2['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_8_BVP_M2))
 
input_file = "Data/S9/Midterm 2/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 9, ExamType = 3)
df_9_BVP_F = new_df.reset_index(drop=True)
df_9_BVP_F.columns=['BVP9','StudentNum','ExamType']
df_9_BVP_M2=df_9_BVP_F.drop(0)
df_9_BVP_M2['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_9_BVP_M2))

input_file = "Data/S10/Midterm 2/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 10, ExamType = 3)
df_10_BVP_F = new_df.reset_index(drop=True)
df_10_BVP_F.columns=['BVP10','StudentNum','ExamType']
df_10_BVP_M2=df_10_BVP_F.drop(0)
df_10_BVP_M2['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_10_BVP_M2))

df_BVP = pd.DataFrame()

df_BVP = df_1_BVP_M2.join(df_2_BVP_M2["BVP2"])
df_BVP = df_BVP.join(df_3_BVP_M2["BVP3"])
df_BVP = df_BVP.join(df_4_BVP_M2["BVP4"])
df_BVP = df_BVP.join(df_5_BVP_M2["BVP5"])
df_BVP = df_BVP.join(df_6_BVP_M2["BVP6"])
df_BVP = df_BVP.join(df_7_BVP_M2["BVP7"])
df_BVP = df_BVP.join(df_8_BVP_M2["BVP8"])
df_BVP = df_BVP.join(df_9_BVP_M2["BVP9"])
df_BVP = df_BVP.join(df_10_BVP_M2["BVP10"])

df_BVP_Midterm2=df_BVP.reindex(columns= ['ExamType','time','BVP1','BVP2','BVP3','BVP4','BVP5','BVP6','BVP7','BVP8','BVP9','BVP10'])

################################################################################################  Final exam

unixts = datetime.datetime.fromtimestamp(1544027337)

input_file = "Data/S1/Final/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 1, ExamType = 1)
df_1_BVP_F = new_df.reset_index(drop=True)
df_1_BVP_F.columns=['BVP1','StudentNum','ExamType']
df_1_BVP_F=df_1_BVP_F.drop(0)
df_1_BVP_F['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_1_BVP_F))
 
input_file = "Data/S2/Final/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 2, ExamType = 1)
df_2_BVP_F = new_df.reset_index(drop=True)
df_2_BVP_F.columns=['BVP2','StudentNum','ExamType']
df_2_BVP_F=df_2_BVP_F.drop(0)
df_2_BVP_F['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_2_BVP_F))
 
input_file = "Data/S3/Final/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 3, ExamType = 1)
df_3_BVP_F = new_df.reset_index(drop=True)
df_3_BVP_F.columns=['BVP3','StudentNum','ExamType']
df_3_BVP_F=df_3_BVP_F.drop(0)
df_3_BVP_F['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_3_BVP_F))

input_file = "Data/S4/Final/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 4, ExamType = 1)
df_4_BVP_F = new_df.reset_index(drop=True)
df_4_BVP_F.columns=['BVP4','StudentNum','ExamType']
df_4_BVP_F=df_4_BVP_F.drop(0)
df_4_BVP_F['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_4_BVP_F))
 
input_file = "Data/S5/Final/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 5, ExamType = 1)
df_5_BVP_F = new_df.reset_index(drop=True)
df_5_BVP_F.columns=['BVP5','StudentNum','ExamType']
df_5_BVP_F=df_5_BVP_F.drop(0)
df_5_BVP_F['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_5_BVP_F))
 
input_file = "Data/S6/Final/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 6, ExamType = 1)
df_6_BVP_F = new_df.reset_index(drop=True)
df_6_BVP_F.columns=['BVP6','StudentNum','ExamType']
df_6_BVP_F=df_6_BVP_F.drop(0)
df_6_BVP_F['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_6_BVP_F))
 
input_file = "Data/S7/Final/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 7, ExamType = 1)
df_7_BVP_F = new_df.reset_index(drop=True)
df_7_BVP_F.columns=['BVP7','StudentNum','ExamType']
df_7_BVP_F=df_7_BVP_F.drop(0)
df_7_BVP_F['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_7_BVP_F))
 
input_file = "Data/S8/Final/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 8, ExamType = 1)
df_8_BVP_F = new_df.reset_index(drop=True)
df_8_BVP_F.columns=['BVP8','StudentNum','ExamType']
df_8_BVP_F=df_8_BVP_F.drop(0)
df_8_BVP_F['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_8_BVP_F))
 
input_file = "Data/S9/Final/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 9, ExamType = 1)
df_9_BVP_F = new_df.reset_index(drop=True)
df_9_BVP_F.columns=['BVP9','StudentNum','ExamType']
df_9_BVP_F=df_9_BVP_F.drop(0)
df_9_BVP_F['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_9_BVP_F))
 
input_file = "Data/S10/Final/BVP.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 10, ExamType = 1)
df_10_BVP_F = new_df.reset_index(drop=True)
df_10_BVP_F.columns=['BVP10','StudentNum','ExamType']
df_10_BVP_F=df_10_BVP_F.drop(0)
df_10_BVP_F['time'] = pd.date_range(unixts, freq='0.015min', periods=len(df_10_BVP_F))
 
df_BVP = df_1_BVP_F.join(df_2_BVP_F["BVP2"])
df_BVP = df_BVP.join(df_3_BVP_F["BVP3"])
df_BVP = df_BVP.join(df_4_BVP_F["BVP4"])
df_BVP = df_BVP.join(df_5_BVP_F["BVP5"])
df_BVP = df_BVP.join(df_6_BVP_F["BVP6"])
df_BVP = df_BVP.join(df_7_BVP_F["BVP7"])
df_BVP = df_BVP.join(df_8_BVP_F["BVP8"])
df_BVP = df_BVP.join(df_9_BVP_F["BVP9"])
df_BVP = df_BVP.join(df_10_BVP_F["BVP10"])

df_BVP_Final=df_BVP.reindex(columns= ['ExamType','time','BVP1','BVP2','BVP3','BVP4','BVP5','BVP6','BVP7','BVP8','BVP9','BVP10'])

######################################################################################### Combining data from all exams
df_BVP = df_BVP_Midterm1.append(df_BVP_Midterm1)
df_BVP = df_BVP.append(df_BVP_Final)
#########################################################################################

# %%
input_file = "Data/S10/Final/BVP.csv"
df = pd.read_csv(input_file)
df
# Out:
#          1544027334.00
# 0                64.00
# 1                -0.00
# 2                -0.00
# 3                -0.00
# 4                -0.00
# ...                ...
# 1476691           4.14
# 1476692           4.17
# 1476693           4.10
# 1476694           3.86
# 1476695           3.43
#
# [1476696 rows x 1 columns]

# %%
df_BVP.to_csv("FinalBVP.csv")
