# %%
import pandas as pd
import datetime

########################################################################################   Midterm1 exam
unixts = datetime.datetime.fromtimestamp(1539435366)

input_file = "Data/S1/Midterm 1/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 1, ExamType = 2)
df_1_EDA_F = new_df.reset_index(drop=True)
df_1_EDA_F.columns=['EDA1','StudentNum','ExamType']
df_1_EDA_M1=df_1_EDA_F.drop(0)
df_1_EDA_M1['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_1_EDA_M1))

input_file = "Data/S2/Midterm 1/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 2, ExamType = 2)
df_2_EDA_F = new_df.reset_index(drop=True)
df_2_EDA_F.columns=['EDA2','StudentNum','ExamType']
df_2_EDA_M1=df_2_EDA_F.drop(0)
df_2_EDA_M1['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_2_EDA_M1))
 
input_file = "Data/S3/Midterm 1/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 3, ExamType = 2)
df_3_EDA_F = new_df.reset_index(drop=True)
df_3_EDA_F.columns=['EDA3','StudentNum','ExamType']
df_3_EDA_M1=df_3_EDA_F.drop(0)
df_3_EDA_M1['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_3_EDA_M1))

input_file = "Data/S4/Midterm 1/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 4, ExamType = 2)
df_4_EDA_F = new_df.reset_index(drop=True)
df_4_EDA_F.columns=['EDA4','StudentNum','ExamType']
df_4_EDA_M1=df_4_EDA_F.drop(0)
df_4_EDA_M1['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_4_EDA_M1))

input_file = "Data/S5/Midterm 1/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 5, ExamType = 2)
df_5_EDA_F = new_df.reset_index(drop=True)
df_5_EDA_F.columns=['EDA5','StudentNum','ExamType']
df_5_EDA_M1=df_5_EDA_F.drop(0)
df_5_EDA_M1['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_5_EDA_M1))

input_file = "Data/S6/Midterm 1/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 6, ExamType = 2)
df_6_EDA_F = new_df.reset_index(drop=True)
df_6_EDA_F.columns=['EDA6','StudentNum','ExamType']
df_6_EDA_M1=df_6_EDA_F.drop(0)
df_6_EDA_M1['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_6_EDA_M1))

input_file = "Data/S7/Midterm 1/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 7, ExamType = 2)
df_7_EDA_F = new_df.reset_index(drop=True)
df_7_EDA_F.columns=['EDA7','StudentNum','ExamType']
df_7_EDA_M1=df_7_EDA_F.drop(0)
df_7_EDA_M1['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_7_EDA_M1))

input_file = "Data/S8/Midterm 1/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 8, ExamType = 2)
df_8_EDA_F = new_df.reset_index(drop=True)
df_8_EDA_F.columns=['EDA8','StudentNum','ExamType']
df_8_EDA_M1=df_8_EDA_F.drop(0)
df_8_EDA_M1['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_8_EDA_M1))
 
input_file = "Data/S9/Midterm 1/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 9, ExamType = 2)
df_9_EDA_F = new_df.reset_index(drop=True)
df_9_EDA_F.columns=['EDA9','StudentNum','ExamType']
df_9_EDA_M1=df_9_EDA_F.drop(0)
df_9_EDA_M1['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_9_EDA_M1))

 
input_file = "Data/S10/Midterm 1/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 10, ExamType = 2)
df_10_EDA_F = new_df.reset_index(drop=True)
df_10_EDA_F.columns=['EDA10','StudentNum','ExamType']
df_10_EDA_M1=df_10_EDA_F.drop(0)
df_10_EDA_M1['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_10_EDA_M1))


df_EDA = df_1_EDA_M1.join(df_2_EDA_M1["EDA2"])
df_EDA = df_EDA.join(df_3_EDA_M1["EDA3"])
df_EDA = df_EDA.join(df_4_EDA_M1["EDA4"])
df_EDA = df_EDA.join(df_5_EDA_M1["EDA5"])
df_EDA = df_EDA.join(df_6_EDA_M1["EDA6"])
df_EDA = df_EDA.join(df_7_EDA_M1["EDA7"])
df_EDA = df_EDA.join(df_8_EDA_M1["EDA8"])
df_EDA = df_EDA.join(df_9_EDA_M1["EDA9"])
df_EDA = df_EDA.join(df_10_EDA_M1["EDA10"])

df_EDA_Midterm1=df_EDA.reindex(columns= ['ExamType','time','EDA1','EDA2','EDA3','EDA4','EDA5','EDA6','EDA7','EDA8','EDA9','EDA10'])

######################################################################################################   Midterm 2 exam

unixts = datetime.datetime.fromtimestamp(1541859555)

input_file = "Data/S1/Midterm 2/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 1, ExamType = 3)
df_1_EDA_F = new_df.reset_index(drop=True)
df_1_EDA_F.columns=['EDA1','StudentNum','ExamType']
df_1_EDA_M2=df_1_EDA_F.drop(0)
df_1_EDA_M2['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_1_EDA_M2))

input_file = "Data/S2/Midterm 2/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 2, ExamType = 3)
df_2_EDA_F = new_df.reset_index(drop=True)
df_2_EDA_F.columns=['EDA2','StudentNum','ExamType']
df_2_EDA_M2=df_2_EDA_F.drop(0)
df_2_EDA_M2['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_2_EDA_M2))
 
input_file = "Data/S3/Midterm 2/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 3, ExamType = 3)
df_3_EDA_F = new_df.reset_index(drop=True)
df_3_EDA_F.columns=['EDA3','StudentNum','ExamType']
df_3_EDA_M2=df_3_EDA_F.drop(0)
df_3_EDA_M2['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_3_EDA_M2))

input_file = "Data/S4/Midterm 2/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 4, ExamType = 3)
df_4_EDA_F = new_df.reset_index(drop=True)
df_4_EDA_F.columns=['EDA4','StudentNum','ExamType']
df_4_EDA_M2=df_4_EDA_F.drop(0)
df_4_EDA_M2['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_4_EDA_M2))

input_file = "Data/S5/Midterm 2/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 5, ExamType = 3)
df_5_EDA_F = new_df.reset_index(drop=True)
df_5_EDA_F.columns=['EDA5','StudentNum','ExamType']
df_5_EDA_M2=df_5_EDA_F.drop(0)
df_5_EDA_M2['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_5_EDA_M2))

input_file = "Data/S6/Midterm 2/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 6, ExamType = 3)
df_6_EDA_F = new_df.reset_index(drop=True)
df_6_EDA_F.columns=['EDA6','StudentNum','ExamType']
df_6_EDA_M2=df_6_EDA_F.drop(0)
df_6_EDA_M2['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_6_EDA_M2))

input_file = "Data/S7/Midterm 2/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 7, ExamType = 3)
df_7_EDA_F = new_df.reset_index(drop=True)
df_7_EDA_F.columns=['EDA7','StudentNum','ExamType']
df_7_EDA_M2=df_7_EDA_F.drop(0)
df_7_EDA_M2['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_7_EDA_M2))

input_file = "Data/S8/Midterm 2/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 8, ExamType = 3)
df_8_EDA_F = new_df.reset_index(drop=True)
df_8_EDA_F.columns=['EDA8','StudentNum','ExamType']
df_8_EDA_M2=df_8_EDA_F.drop(0)
df_8_EDA_M2['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_8_EDA_M2))
 
input_file = "Data/S9/Midterm 2/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 9, ExamType = 3)
df_9_EDA_F = new_df.reset_index(drop=True)
df_9_EDA_F.columns=['EDA9','StudentNum','ExamType']
df_9_EDA_M2=df_9_EDA_F.drop(0)
df_9_EDA_M2['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_9_EDA_M2))

input_file = "Data/S10/Midterm 2/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 10, ExamType = 3)
df_10_EDA_F = new_df.reset_index(drop=True)
df_10_EDA_F.columns=['EDA10','StudentNum','ExamType']
df_10_EDA_M2=df_10_EDA_F.drop(0)
df_10_EDA_M2['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_10_EDA_M2))

df_EDA = pd.DataFrame()

df_EDA = df_1_EDA_M2.join(df_2_EDA_M2["EDA2"])
df_EDA = df_EDA.join(df_3_EDA_M2["EDA3"])
df_EDA = df_EDA.join(df_4_EDA_M2["EDA4"])
df_EDA = df_EDA.join(df_5_EDA_M2["EDA5"])
df_EDA = df_EDA.join(df_6_EDA_M2["EDA6"])
df_EDA = df_EDA.join(df_7_EDA_M2["EDA7"])
df_EDA = df_EDA.join(df_8_EDA_M2["EDA8"])
df_EDA = df_EDA.join(df_9_EDA_M2["EDA9"])
df_EDA = df_EDA.join(df_10_EDA_M2["EDA10"])

df_EDA_Midterm2=df_EDA.reindex(columns= ['ExamType','time','EDA1','EDA2','EDA3','EDA4','EDA5','EDA6','EDA7','EDA8','EDA9','EDA10'])

################################################################################################  Final exam

unixts = datetime.datetime.fromtimestamp(1544027337)

input_file = "Data/S1/Final/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 1, ExamType = 1)
df_1_EDA_F = new_df.reset_index(drop=True)
df_1_EDA_F.columns=['EDA1','StudentNum','ExamType']
df_1_EDA_F=df_1_EDA_F.drop(0)
df_1_EDA_F['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_1_EDA_F))
 
input_file = "Data/S2/Final/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 2, ExamType = 1)
df_2_EDA_F = new_df.reset_index(drop=True)
df_2_EDA_F.columns=['EDA2','StudentNum','ExamType']
df_2_EDA_F=df_2_EDA_F.drop(0)
df_2_EDA_F['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_2_EDA_F))
 
input_file = "Data/S3/Final/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 3, ExamType = 1)
df_3_EDA_F = new_df.reset_index(drop=True)
df_3_EDA_F.columns=['EDA3','StudentNum','ExamType']
df_3_EDA_F=df_3_EDA_F.drop(0)
df_3_EDA_F['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_3_EDA_F))

input_file = "Data/S4/Final/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 4, ExamType = 1)
df_4_EDA_F = new_df.reset_index(drop=True)
df_4_EDA_F.columns=['EDA4','StudentNum','ExamType']
df_4_EDA_F=df_4_EDA_F.drop(0)
df_4_EDA_F['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_4_EDA_F))
 
input_file = "Data/S5/Final/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 5, ExamType = 1)
df_5_EDA_F = new_df.reset_index(drop=True)
df_5_EDA_F.columns=['EDA5','StudentNum','ExamType']
df_5_EDA_F=df_5_EDA_F.drop(0)
df_5_EDA_F['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_5_EDA_F))
 
input_file = "Data/S6/Final/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 6, ExamType = 1)
df_6_EDA_F = new_df.reset_index(drop=True)
df_6_EDA_F.columns=['EDA6','StudentNum','ExamType']
df_6_EDA_F=df_6_EDA_F.drop(0)
df_6_EDA_F['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_6_EDA_F))
 
input_file = "Data/S7/Final/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 7, ExamType = 1)
df_7_EDA_F = new_df.reset_index(drop=True)
df_7_EDA_F.columns=['EDA7','StudentNum','ExamType']
df_7_EDA_F=df_7_EDA_F.drop(0)
df_7_EDA_F['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_7_EDA_F))
 
input_file = "Data/S8/Final/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 8, ExamType = 1)
df_8_EDA_F = new_df.reset_index(drop=True)
df_8_EDA_F.columns=['EDA8','StudentNum','ExamType']
df_8_EDA_F=df_8_EDA_F.drop(0)
df_8_EDA_F['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_8_EDA_F))
 
input_file = "Data/S9/Final/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 9, ExamType = 1)
df_9_EDA_F = new_df.reset_index(drop=True)
df_9_EDA_F.columns=['EDA9','StudentNum','ExamType']
df_9_EDA_F=df_9_EDA_F.drop(0)
df_9_EDA_F['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_9_EDA_F))
 
input_file = "Data/S10/Final/EDA.csv"
df = pd.read_csv(input_file)
new_df=df.assign(StudentNum= 10, ExamType = 1)
df_10_EDA_F = new_df.reset_index(drop=True)
df_10_EDA_F.columns=['EDA10','StudentNum','ExamType']
df_10_EDA_F=df_10_EDA_F.drop(0)
df_10_EDA_F['time'] = pd.date_range(unixts, freq='0.25min', periods=len(df_10_EDA_F))
 
df_EDA = df_1_EDA_F.join(df_2_EDA_F["EDA2"])
df_EDA = df_EDA.join(df_3_EDA_F["EDA3"])
df_EDA = df_EDA.join(df_4_EDA_F["EDA4"])
df_EDA = df_EDA.join(df_5_EDA_F["EDA5"])
df_EDA = df_EDA.join(df_6_EDA_F["EDA6"])
df_EDA = df_EDA.join(df_7_EDA_F["EDA7"])
df_EDA = df_EDA.join(df_8_EDA_F["EDA8"])
df_EDA = df_EDA.join(df_9_EDA_F["EDA9"])
df_EDA = df_EDA.join(df_10_EDA_F["EDA10"])

df_EDA_Final=df_EDA.reindex(columns= ['ExamType','time','EDA1','EDA2','EDA3','EDA4','EDA5','EDA6','EDA7','EDA8','EDA9','EDA10'])

######################################################################################### Combining data from all exams
df_EDA = df_EDA_Midterm1.append(df_EDA_Midterm1)
df_EDA = df_EDA.append(df_EDA_Final)
#########################################################################################

# %%
df_EDA
# Out:
#        ExamType                time      EDA1      EDA2      EDA3      EDA4  \
# 1             2 2018-10-13 08:56:06  0.000000  0.000000  0.000000  0.000000
# 2             2 2018-10-13 08:56:21  0.002563  0.003844  0.001282  0.002563
# 3             2 2018-10-13 08:56:36  0.019221  0.016658  0.016660  0.016656
# 4             2 2018-10-13 08:56:51  0.021784  0.017940  0.017942  0.016656
# 5             2 2018-10-13 08:57:06  0.023065  0.017940  0.016660  0.017938
# ...         ...                 ...       ...       ...       ...       ...
# 93578         1 2018-12-21 17:23:12  0.025627  0.015376  0.000000       NaN
# 93579         1 2018-12-21 17:23:27  0.025627  0.014095  0.000000       NaN
# 93580         1 2018-12-21 17:23:42  0.026908  0.014095  0.000000       NaN
# 93581         1 2018-12-21 17:23:57  0.025627  0.015376  0.000000       NaN
# 93582         1 2018-12-21 17:24:12  0.026908  0.015376  0.000000       NaN
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#plt.style.use('dark_background')
## Electordermal activity plot
sns.set(style='whitegrid', rc={'axes.facecolor': '#EFF2F7'})
plt.plot
settings = {}
settings['fs'] = 390
start = 0
stop = 23387
duration = (stop-start) / settings['fs']


#################################### midterm 1 plot

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 1, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm1[start:stop].time, df_EDA_Midterm1[start:stop].EDA1, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 2, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm1[start:stop].time, df_EDA_Midterm1[start:stop].EDA2, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 3, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm1[start:stop].time, df_EDA_Midterm1[start:stop].EDA3, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 4, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm1[start:stop].time, df_EDA_Midterm1[start:stop].EDA4, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 5, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm1[start:stop].time, df_EDA_Midterm1[start:stop].EDA5, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 6, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm1[start:stop].time, df_EDA_Midterm1[start:stop].EDA6, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 7, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm1[start:stop].time, df_EDA_Midterm1[start:stop].EDA7, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)") 
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 8, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm1[start:stop].time, df_EDA_Midterm1[start:stop].EDA8, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 9, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm1[start:stop].time, df_EDA_Midterm1[start:stop].EDA9, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 10, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm1[start:stop].time, df_EDA_Midterm1[start:stop].EDA10, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

########################################### Midterm 2 plot

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 1, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm2[start:stop].time, df_EDA_Midterm2[start:stop].EDA1, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 2, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm2[start:stop].time, df_EDA_Midterm2[start:stop].EDA2, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 3, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm2[start:stop].time, df_EDA_Midterm2[start:stop].EDA3, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 4, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm2[start:stop].time, df_EDA_Midterm2[start:stop].EDA4, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 5, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm2[start:stop].time, df_EDA_Midterm2[start:stop].EDA5, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 6, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm2[start:stop].time, df_EDA_Midterm2[start:stop].EDA6, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 7, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm2[start:stop].time, df_EDA_Midterm2[start:stop].EDA7, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 8, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm2[start:stop].time, df_EDA_Midterm2[start:stop].EDA8, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 9, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm2[start:stop].time, df_EDA_Midterm2[start:stop].EDA9, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 10, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Midterm2[start:stop].time, df_EDA_Midterm2[start:stop].EDA10, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()


########################### final plot

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 1, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Final[start:stop].time, df_EDA_Final[start:stop].EDA1, color="#51A6D8", linewidth=0.5)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 2, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Final[start:stop].time, df_EDA_Final[start:stop].EDA2, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 3, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Final[start:stop].time, df_EDA_Final[start:stop].EDA3, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 4, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Final[start:stop].time, df_EDA_Final[start:stop].EDA4, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 5, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Final[start:stop].time, df_EDA_Final[start:stop].EDA5, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 6, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Final[start:stop].time, df_EDA_Final[start:stop].EDA6, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 7, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Final[start:stop].time, df_EDA_Final[start:stop].EDA7, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 8, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Final[start:stop].time, df_EDA_Final[start:stop].EDA8, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 9, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Final[start:stop].time, df_EDA_Final[start:stop].EDA9, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

plt.figure(figsize=(20, 2))
plt.title("Electordermal activity for student 10, slice of %.1f seconds" % duration)
plt.plot(df_EDA_Final[start:stop].time, df_EDA_Final[start:stop].EDA10, color="#51A6D8", linewidth=1)
plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)")
plt.show()

# %%
df_EDA.to_csv("FinalEDA.csv")
